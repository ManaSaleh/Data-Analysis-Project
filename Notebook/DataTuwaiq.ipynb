# %% [markdown]
# # **Data Aanlysis**

# %% [markdown]
# <img src ='images/Picture1.png'>

# %% [markdown]
# ## 1- Define Question

# %% [markdown]
# ### What specific criteria will be used to define "success" in the context of completing the rigorous training curriculum?

# %% [markdown]
# ## 2-Data Loading and Preprocessing

# %% [markdown]
# **Step 1 Collect data**:
# Ddata already exists .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler , LabelEncoder , OrdinalEncoder

# %% [markdown]
# **Step 2 Understanding Data**

# %%
df_train = pd.read_csv('measuring-student-persistence-and-completion-rate/train.csv')

# %%
df_test = pd.read_csv('measuring-student-persistence-and-completion-rate/test.csv')

# %%
df_reg = pd.read_csv('measuring-student-persistence-and-completion-rate/registration.csv')

# %%
df_train.head()
# Out:
#                              Student ID   Age Gender   Home Region  Home City  \
# 0  4f14c50d-162e-4a15-9cf0-ec129c33bcf0  37.0    ذكر  منطقة الرياض     الرياض
# 1  0599d409-876b-41a5-af05-749ef0e77d32  21.0    ذكر    منطقة عسير  خميس مشيط
# 2  38a11c0e-4afc-4261-9c64-e94cc0a272fb  24.0    ذكر  منطقة الرياض     الرياض
# 3  1693e85b-f80e-40ce-846f-395ddcece6d3  23.0    ذكر  منطقة الرياض     الرياض
# 4  98a0e8d0-5f80-4634-afd8-322aa0902863  23.0    ذكر  منطقة الرياض     الرياض
#
#                              Program ID Program Main Category Code  \
# 0  453686d8-4023-4506-b2df-fac8b059ac26                       PCRF
# 1  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60                       APMR
# 2  e006900d-05a9-4c2b-a36f-0ffb9fce44cd                       APMR
# 3  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9                       TOSL
# 4  d32da0e9-1aed-48c3-992d-a22f9ccc741e                       CAUF
#
#   Program Sub Category Code Technology Type Program Skill Level  ...  \
# 0                      PCRF             NaN                 NaN  ...
# 1                      SWPS             NaN               متوسط  ...
# 2                       NaN             NaN               متوسط  ...
# 3                      TOSL             NaN                 NaN  ...
# 4                      SWPS         تقليدية               متوسط  ...
#
#   Completed Degree Level of Education                Education Speaciality  \
# 0              نعم        البكالوريوس                     هندسة حاسب الالي
# 1              نعم        البكالوريوس           الإذاعة والتلفزيون والفيلم
# 2              نعم        البكالوريوس               Information Technology
# 3              نعم        البكالوريوس  حوسبة تطبيقية - (مسار شبكات الحاسب)
# 4               لا        البكالوريوس              نظم المعلومات الحاسوبية
#
#                           College University Degree Score  \
# 0                             NaN                    2.44
# 1        الفنون والعلوم الإنسانية                    5.00
# 2                             NaN                    3.50
# 3                             NaN                    3.55
# 4  تكنولوجيا الاتصالات والمعلومات                    4.00
#
#   University Degree Score System Employment Status Job Type  Still Working  Y
# 0                            4.0          غير موظف      NaN            NaN  0
# 1                            5.0              طالب      NaN            NaN  0
# 2                            5.0              موظف      NaN            NaN  0
# 3                            5.0              خريج      NaN            NaN  0
# 4                            5.0               NaN      NaN            NaN  0
#
# [5 rows x 24 columns]

# %%
df_test.head()
# Out:
#                              Student ID   Age Gender   Home Region Home City  \
# 0  d8524ed6-a1b2-4f6f-9041-66eebcab899a  23.0   أنثى  منطقة الرياض    الرياض
# 1  5490b973-d85e-4b26-93a8-ecc11c47a5a0  31.0   أنثى  منطقة الرياض    الرياض
# 2  3c1d99c8-f25b-4198-b904-aacb15164888  29.0   أنثى  منطقة الرياض    الرياض
# 3  9e57ee90-2d60-48b8-91a1-7caa49f03810  23.0   أنثى  منطقة الرياض    الرياض
# 4  a11b482b-6cc3-4e1a-8b95-60ab2e42097a  30.0   أنثى  منطقة الرياض    الرياض
#
#                              Program ID Program Main Category Code  \
# 0  451d680f-e067-41c0-a998-6b3da3963bca                       CAUF
# 1  4957a013-46a7-419c-93d5-ebf3741ab2a1                       PCRF
# 2  03ec0d20-11cd-49bf-9b54-de5d12d4bd76                       CAUF
# 3  4ad7a7dc-abcf-43fa-b2e3-07095e083661                       PCRF
# 4  60494e5b-b20a-4440-ab75-0fd257748dcc                       TOSL
#
#   Program Sub Category Code Technology Type Program Skill Level  ...  \
# 0                      SWPS         تقليدية               متوسط  ...
# 1                      PCRF         تقليدية               مبتدئ  ...
# 2                      SWPS             NaN                 NaN  ...
# 3                      PCRF             NaN               متقدم  ...
# 4                       NaN           داعمة               متقدم  ...
#
#   Program Days Completed Degree Level of Education  Education Speaciality  \
# 0            5               لا        البكالوريوس      علوم الحاسب الالي
# 1           19               لا        البكالوريوس        تقنية المعلومات
# 2           12              نعم        البكالوريوس     شبكات الحاسب الآلي
# 3            5              نعم        البكالوريوس                Biology
# 4           33              نعم            الدبلوم        تقنية المعلومات
#
#                           College University Degree Score  \
# 0                             NaN                    3.72
# 1  تكنولوجيا الاتصالات والمعلومات                    2.00
# 2  تكنولوجيا الاتصالات والمعلومات                    3.72
# 3                             NaN                    4.47
# 4  تكنولوجيا الاتصالات والمعلومات                    4.46
#
#   University Degree Score System Employment Status   Job Type  Still Working
# 0                            4.0              خريج        NaN            NaN
# 1                            4.0               NaN        NaN            NaN
# 2                            5.0              موظف  دوام كامل            Yes
# 3                            5.0          غير موظف        NaN            NaN
# 4                            5.0          غير موظف  دوام كامل             No
#
# [5 rows x 23 columns]

# %%
df_reg.sample(8)
# Out:
#                                 Student ID  PCRF  GRST  CAUF  INFA  ABIR  \
# 3189  840dfd18-758a-4993-ada6-753838e4a049    12     4     2     3     0
# 3220  857d78b5-316d-49dd-a67c-adfca169303a     4     0     1     0     0
# 2484  6736fd42-2d94-4716-a50b-4e81a739bf8c     0     0     2     0     0
# 1865  4d2f3ac3-284b-45db-b46d-a4745c69aabb     4     1     8     1     0
# 659   1b9c437a-333c-4f2b-9e5c-da3ec32b015b     2     0     0     0     0
# 37    019e6eea-a941-4598-87f0-add9efe832d5     0     0     2     0     0
# 2904  78168090-a658-44a1-aaaa-7d540f2f5939     0     0     4     0     0
# 4260  b0bf2d7b-3957-4858-a7e5-d7d0a3fef37a     0     0     0     1     0
#
#       SERU  TOSL  APMR  DTFH  QWLM  N/A  Total Regestration
# 3189     0     0     2     0     0    4                  27
# 3220     0     0     2     0     0    0                   7
# 2484     0     0     5     0     0    3                  10
# 1865     0     0     2     0     0    0                  16
# 659      0     0     0     0     0    0                   2
# 37       0     0     0     0     0    2                   4
# 2904     1     0     1     0     0    1                   7
# 4260     0     0     1     0     0    0                   2

# %%
df_train.columns
# Out:
# Index(['Student ID', 'Age', 'Gender', 'Home Region', 'Home City', 'Program ID',
#        'Program Main Category Code', 'Program Sub Category Code',
#        'Technology Type', 'Program Skill Level', 'Program Presentation Method',
#        'Program Start Date', 'Program End Date', 'Program Days',
#        'Completed Degree', 'Level of Education', 'Education Speaciality',
#        'College', 'University Degree Score', 'University Degree Score System',
#        'Employment Status', 'Job Type', 'Still Working', 'Y'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (6548, 24)

# %%
df_test.shape
# Out:
# (818, 23)

# %%
df_train.dtypes
# Out:
# Student ID                         object
# Age                               float64
# Gender                             object
# Home Region                        object
# Home City                          object
# Program ID                         object
# Program Main Category Code         object
# Program Sub Category Code          object
# Technology Type                    object
# Program Skill Level                object
# Program Presentation Method        object
# Program Start Date                 object
# Program End Date                   object
# Program Days                        int64
# Completed Degree                   object
# Level of Education                 object
# Education Speaciality              object
# College                            object
# University Degree Score           float64
# University Degree Score System    float64
# Employment Status                  object
# Job Type                           object
# Still Working                      object
# Y                                   int64
# dtype: object

# %%
df_train.describe()
# Out:
#                Age  Program Days  University Degree Score  \
# count  6456.000000   6548.000000              6467.000000
# mean     26.831165     19.691662                 8.224432
# std       5.535967     32.112061                19.120384
# min      18.000000      3.000000                 0.000000
# 25%      23.000000      5.000000                 3.300000
# 50%      25.000000     12.000000                 4.000000
# 75%      29.000000     19.000000                 4.510000
# max      57.000000    292.000000               100.000000
#
#        University Degree Score System            Y
# count                     6467.000000  6548.000000
# mean                         9.773929     0.158674
# std                         21.259962     0.365400
# min                          4.000000     0.000000
# 25%                          5.000000     0.000000
# 50%                          5.000000     0.000000
# 75%                          5.000000     0.000000
# max                        100.000000     1.000000

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))
sns.boxplot(data=df_train, orient="h", palette="Set2")
plt.title('Box plots of Numerical Columns')
plt.xlabel('Value')
# Out:
# Text(0.5, 0, 'Value')

# %%
df_train.describe().transpose()
# Out:
#                                  count       mean        std   min   25%  \
# Age                             6456.0  26.831165   5.535967  18.0  23.0
# Program Days                    6548.0  19.691662  32.112061   3.0   5.0
# University Degree Score         6467.0   8.224432  19.120384   0.0   3.3
# University Degree Score System  6467.0   9.773929  21.259962   4.0   5.0
# Y                               6548.0   0.158674   0.365400   0.0   0.0
#
#                                  50%    75%    max
# Age                             25.0  29.00   57.0
# Program Days                    12.0  19.00  292.0
# University Degree Score          4.0   4.51  100.0
# University Degree Score System   5.0   5.00  100.0
# Y                                0.0   0.00    1.0

# %%
df_train.describe(include = "all")
# Out:
#                                   Student ID          Age Gender  \
# count                                   6548  6456.000000   6548
# unique                                  5196          NaN      2
# top     415cfcb1-8dfa-459d-b719-d942cc5e19e1          NaN   أنثى
# freq                                       9          NaN   3664
# mean                                     NaN    26.831165    NaN
# std                                      NaN     5.535967    NaN
# min                                      NaN    18.000000    NaN
# 25%                                      NaN    23.000000    NaN
# 50%                                      NaN    25.000000    NaN
# 75%                                      NaN    29.000000    NaN
# max                                      NaN    57.000000    NaN
#
#          Home Region Home City                            Program ID  \
# count           6546      6546                                  6548
# unique            13        92                                   223
# top     منطقة الرياض    الرياض  ab263106-20a8-42aa-9626-278e62ae3a49
# freq            4783      4720                                   134
# mean             NaN       NaN                                   NaN
# std              NaN       NaN                                   NaN
# min              NaN       NaN                                   NaN
# 25%              NaN       NaN                                   NaN
# 50%              NaN       NaN                                   NaN
# 75%              NaN       NaN                                   NaN
# max              NaN       NaN                                   NaN
#
#        Program Main Category Code Program Sub Category Code Technology Type  \
# count                        6548                      5613            3566
# unique                         10                        11               3
# top                          CAUF                      SWPS         تقليدية
# freq                         2358                      1788            2693
# mean                          NaN                       NaN             NaN
# std                           NaN                       NaN             NaN
# min                           NaN                       NaN             NaN
# 25%                           NaN                       NaN             NaN
# 50%                           NaN                       NaN             NaN
# 75%                           NaN                       NaN             NaN
# max                           NaN                       NaN             NaN
#
#        Program Skill Level  ... Completed Degree Level of Education  \
# count                 4902  ...             6548               6522
# unique                   3  ...                2                  5
# top                  متوسط  ...              نعم        البكالوريوس
# freq                  2134  ...             5206               5429
# mean                   NaN  ...              NaN                NaN
# std                    NaN  ...              NaN                NaN
# min                    NaN  ...              NaN                NaN
# 25%                    NaN  ...              NaN                NaN
# 50%                    NaN  ...              NaN                NaN
# 75%                    NaN  ...              NaN                NaN
# max                    NaN  ...              NaN                NaN
#
#        Education Speaciality                         College  \
# count                   6271                            2658
# unique                   871                               9
# top            علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# freq                    1067                            2312
# mean                     NaN                             NaN
# std                      NaN                             NaN
# min                      NaN                             NaN
# 25%                      NaN                             NaN
# 50%                      NaN                             NaN
# 75%                      NaN                             NaN
# max                      NaN                             NaN
#
#        University Degree Score University Degree Score System  \
# count              6467.000000                    6467.000000
# unique                     NaN                            NaN
# top                        NaN                            NaN
# freq                       NaN                            NaN
# mean                  8.224432                       9.773929
# std                  19.120384                      21.259962
# min                   0.000000                       4.000000
# 25%                   3.300000                       5.000000
# 50%                   4.000000                       5.000000
# 75%                   4.510000                       5.000000
# max                 100.000000                     100.000000
#
#        Employment Status   Job Type  Still Working            Y
# count               5982       1981           1981  6548.000000
# unique                 6          4              2          NaN
# top                 موظف  دوام كامل            Yes          NaN
# freq                2801       1398           1246          NaN
# mean                 NaN        NaN            NaN     0.158674
# std                  NaN        NaN            NaN     0.365400
# min                  NaN        NaN            NaN     0.000000
# 25%                  NaN        NaN            NaN     0.000000
# 50%                  NaN        NaN            NaN     0.000000
# 75%                  NaN        NaN            NaN     0.000000
# max                  NaN        NaN            NaN     1.000000
#
# [11 rows x 24 columns]

# %%
df_reg.describe()
# Out:
#               PCRF         GRST         CAUF         INFA         ABIR  \
# count  6171.000000  6171.000000  6171.000000  6171.000000  6171.000000
# mean      1.525847     0.233025     2.462972     0.763734     0.080538
# std       2.826037     0.556516     3.675233     1.410859     0.320295
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     1.000000     0.000000     0.000000
# 75%       2.000000     0.000000     3.000000     1.000000     0.000000
# max      27.000000     4.000000    45.000000    13.000000     4.000000
#
#               SERU    TOSL         APMR         DTFH         QWLM  \
# count  6171.000000  6171.0  6171.000000  6171.000000  6171.000000
# mean      0.061254     0.0     1.412899     0.002755     0.009561
# std       0.248446     0.0     2.263584     0.055424     0.097319
# min       0.000000     0.0     0.000000     0.000000     0.000000
# 25%       0.000000     0.0     0.000000     0.000000     0.000000
# 50%       0.000000     0.0     0.000000     0.000000     0.000000
# 75%       0.000000     0.0     2.000000     0.000000     0.000000
# max       2.000000     0.0    19.000000     2.000000     1.000000
#
#                N/A  Total Regestration
# count  6171.000000         6171.000000
# mean      1.691298            8.308702
# std       3.618898            9.613899
# min       0.000000            1.000000
# 25%       0.000000            2.000000
# 50%       0.000000            5.000000
# 75%       2.000000           11.000000
# max      47.000000          109.000000

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6548 entries, 0 to 6547
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Student ID                      6548 non-null   object
#  1   Age                             6456 non-null   float64
#  2   Gender                          6548 non-null   object
#  3   Home Region                     6546 non-null   object
#  4   Home City                       6546 non-null   object
#  5   Program ID                      6548 non-null   object
#  6   Program Main Category Code      6548 non-null   object
#  7   Program Sub Category Code       5613 non-null   object
#  8   Technology Type                 3566 non-null   object
#  9   Program Skill Level             4902 non-null   object
#  10  Program Presentation Method     6548 non-null   object
#  11  Program Start Date              6548 non-null   object
#  12  Program End Date                6548 non-null   object
#  13  Program Days                    6548 non-null   int64
#  14  Completed Degree                6548 non-null   object
#  15  Level of Education              6522 non-null   object
#  16  Education Speaciality           6271 non-null   object
#  17  College                         2658 non-null   object
#  18  University Degree Score         6467 non-null   float64
#  19  University Degree Score System  6467 non-null   float64
#  20  Employment Status               5982 non-null   object
#  21  Job Type                        1981 non-null   object
#  22  Still Working                   1981 non-null   object
#  23  Y                               6548 non-null   int64
# dtypes: float64(3), int64(2), object(19)
# memory usage: 1.2+ MB

# %%
sample_data = df_train[['Completed Degree', 'Y']].sample(20)
sample_data.head()
# Out:
#      Completed Degree  Y
# 136               نعم  0
# 2131              نعم  0
# 644               نعم  0
# 1946              نعم  0
# 203               نعم  0

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

sns.countplot(x='Completed Degree', data=sample_data, ax=axes[0])
axes[0].set_title('Distribution of Completed Degrees')
axes[0].set_xlabel('Completed Degree')
axes[0].set_ylabel('Count')

sns.countplot(x='Y', data=sample_data, ax=axes[1])
axes[1].set_title('Distribution of Target Variable (Y)')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('Count')

plt.tight_layout()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x='Completed Degree', hue='Y', data=df_train, palette='Set2')
plt.title('Count of Completed Degree by Y')
plt.xlabel('Completed Degree')
plt.ylabel('Count')
plt.legend(title='Y', loc='upper right')

# %%
df_train['Program Main Category Code'].value_counts()
# Out:
# Program Main Category Code
# CAUF    2358
# PCRF    1682
# APMR    1299
# TOSL     500
# GRST     208
# ABIR     205
# INFA     179
# SERU      53
# DTFH      33
# QWLM      31
# Name: count, dtype: int64

# %%
df_train['Program Sub Category Code'].value_counts()
# Out:
# Program Sub Category Code
# SWPS    1788
# PCRF    1682
# SRTA     700
# INFA     510
# TOSL     295
# CRDP     243
# ERST     172
# KLTM     117
# QTDY      51
# ASCW      36
# ABIR      19
# Name: count, dtype: int64

# %%
tech_type_counts = df_train['Technology Type'].value_counts()

# %%
plt.figure(figsize=(10, 6))
tech_type_counts.plot(kind='bar', color='lightgreen')
plt.title('Distribution of Technology Types')
plt.xlabel('Technology Type')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.tight_layout()

# %%
skill_level_counts = df_train['Program Skill Level'].value_counts()

# %%
plt.figure(figsize=(8, 6))
skill_level_counts.plot(kind='bar', color='lightblue')
plt.title('Distribution of Program Skill Levels')
plt.xlabel('Skill Level')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.tight_layout()

# %%
df_train['Completed Degree'].value_counts()
# Out:
# Completed Degree
# نعم    5206
# لا     1342
# Name: count, dtype: int64

# %%
education_level_counts = df_train['Level of Education'].value_counts()

# %%
plt.figure(figsize=(8, 6))
education_level_counts.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Level of Education')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.tight_layout()

# %%
count_education_y = ((df_train['Level of Education'] == 'البكالوريوس') & (df_train['Y'] == 0)).sum()

# %%
((df_train['Level of Education'] == 'الماجستير') & (df_train['Y'] == 0)).sum()
# Out:
# 416

# %%
((df_train['Level of Education'] == 'الدبلوم') & (df_train['Y'] == 0)).sum()
# Out:
# 250

# %%
((df_train['Level of Education'] == 'ثانوي') & (df_train['Y'] == 0)).sum()
# Out:
# 196

# %%
((df_train['Level of Education'] == 'الدكتوراه') & (df_train['Y'] == 0)).sum()
# Out:
# 24

# %%
df_train['Y'] = df_train['Y'].map({0: 'pass', 1: 'not pass'})

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x='Level of Education', hue='Y', data=df_train)
plt.title('Distribution of Target Variable (Y) by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45) 

# Custom legend
plt.legend(title='Y', labels=['Pass', 'Not Pass'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
df_train['College'].value_counts()
# Out:
# College
# تكنولوجيا الاتصالات والمعلومات         2312
# الأعمال والإدارة والقانون               153
# العلوم الطبيعية والرياضيات والإحصاء      62
# الهندسة والتصنيع والبناء                 43
# الفنون والعلوم الإنسانية                 38
# العلوم الاجتماعية والصحافة والإعلام      25
# التعليم                                  19
# الصحة والرفاة                             4
# البرامج والمؤهلات العامة                  2
# Name: count, dtype: int64

# %%
score_system_counts = df_train['University Degree Score System'].value_counts()

# %%
plt.figure(figsize=(8, 6))
score_system_counts.plot(kind='bar', color='lightgreen')
plt.title('Distribution of University Degree Score System')
plt.xlabel('Score System')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.tight_layout()

# %%
employment_status_counts = df_train['Employment Status'].value_counts()

# %%
plt.figure(figsize=(8, 6))
employment_status_counts.plot(kind='bar', color='lightblue')
plt.title('Distribution of Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.tight_layout()

# %%
df_train['Job Type'].value_counts()
# Out:
# Job Type
# دوام كامل    1398
# تدريب         478
# دوام جزئي      61
# تطوع           44
# Name: count, dtype: int64

# %%
df_train['Still Working'].value_counts()
# Out:
# Still Working
# Yes    1246
# No      735
# Name: count, dtype: int64

# %%
df_train[['Program Main Category Code' , 'Program Sub Category Code' ,'Y']].sample(10)
# Out:
#      Program Main Category Code Program Sub Category Code         Y
# 1128                       APMR                      QTDY      pass
# 3513                       APMR                      SRTA      pass
# 5355                       CAUF                      SWPS      pass
# 4005                       PCRF                      PCRF      pass
# 79                         ABIR                      INFA      pass
# 6482                       PCRF                      PCRF      pass
# 869                        CAUF                      SWPS  not pass
# 152                        APMR                      SRTA      pass
# 4912                       CAUF                      SWPS      pass
# 233                        CAUF                      SWPS      pass

# %%
# Generate random data for illustration
np.random.seed(0)
gender = np.random.choice(['Male', 'Female'], size=100)
age = np.random.randint(18, 65, size=100)
completed_degree = np.random.choice(['Yes', 'No'], size=100)
score = np.random.randint(50, 100, size=100)

df = pd.DataFrame({'Gender': gender, 'Age': age, 'Completed Degree': completed_degree, 'Score': score})

# Visualize the distribution of completed degrees by gender
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Completed Degree', hue='Gender')
plt.title('Distribution of Completed Degrees by Gender')
plt.xlabel('Completed Degree')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# Visualize the distribution of scores by completed degree
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Completed Degree', y='Score')
plt.title('Distribution of Scores by Completed Degree')
plt.xlabel('Completed Degree')
plt.ylabel('Score')
plt.show()

# Statistical summary
summary_stats = df.groupby('Completed Degree')['Score'].describe()
print(summary_stats)

# Concluding remarks
print("\nConcluding Remarks:")
print("The analysis reveals that there is a difference in the distribution of completed degrees by gender.")
print("Additionally, the distribution of scores varies based on whether the degree is completed or not.")
# Out:
#                   count       mean        std   min   25%   50%   75%   max
# Completed Degree
# No                 61.0  74.081967  14.387836  50.0  64.0  74.0  85.0  99.0
# Yes                39.0  76.051282  12.565510  52.0  67.0  79.0  85.5  98.0
#
# Concluding Remarks:
# The analysis reveals that there is a difference in the distribution of completed degrees by gender.
# Additionally, the distribution of scores varies based on whether the degree is completed or not.

# %% [markdown]
# **Step 3 Data Wrangling - Cleaning**

# %% [markdown]
# Data wrangling, also known as preprocessing, is the process of transforming raw data into a more suitable format for analysis, ensuring data quality and usability:

# %% [markdown]
# - **Handling Missing Values**: the process involves identifying and addressing missing or null values in a dataset by either replacing them with appropriate values or removing them entirely.

# %%
df_train.isnull().sum()
# Out:
# Student ID                           0
# Age                                 92
# Gender                               0
# Home Region                          2
# Home City                            2
# Program ID                           0
# Program Main Category Code           0
# Program Sub Category Code          935
# Technology Type                   2982
# Program Skill Level               1646
# Program Presentation Method          0
# Program Start Date                   0
# Program End Date                     0
# Program Days                         0
# Completed Degree                     0
# Level of Education                  26
# Education Speaciality              277
# College                           3890
# University Degree Score             81
# University Degree Score System      81
# Employment Status                  566
# Job Type                          4567
# Still Working                     4567
# Y                                    0
# dtype: int64

# %%
df_train.replace("?", np.NaN, inplace = True)

# %% [markdown]
# ### Deal with missing data
# <b>How should you deal with missing data?</b>
#
# <ol>
#     <li>Drop data<br>
#         a. Drop the whole row<br>
#         b. Drop the whole column
#     </li>
#     <li>Replace data<br>
#         a. Replace it by mean<br>
#         b. Replace it by frequency<br>
#         c. Replace it based on other functions
#     </li>
# </ol>

# %%
# Replace 'median_age' with the actual median age in tarin
median_age = df_train['Age'].median()
print(f'The median of student is {median_age}')
# Fill missing values in the 'Age' column with the median age
df_train['Age'].fillna(median_age, inplace=True)
# Out:
# The median of student is 25.0
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2941124194.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Age'].fillna(median_age, inplace=True)

# %%
# Replace 'median_age' with the actual median age in test
median_aget = df_test['Age'].median()
print(f'The median of student is {median_aget}')
# Fill missing values in the 'Age' column with the median age
df_test['Age'].fillna(median_aget, inplace=True)
# Out:
# The median of student is 25.0
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2517186433.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Age'].fillna(median_aget, inplace=True)

# %%
# Fill missing values in the 'Home Region' column with the mode in tarin
mode_home_region = df_train['Home Region'].mode()[0]
df_train['Home Region'].fillna(mode_home_region, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\400505764.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Home Region'].fillna(mode_home_region, inplace=True)

# %%
# Fill missing values in the 'Home Region' column with the mode in tarin
mode_home_region = df_train['Home City'].mode()[0]
df_train['Home City'].fillna(mode_home_region, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\3982742740.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Home City'].fillna(mode_home_region, inplace=True)

# %%
# Fill missing values in the 'Home Region' column with the mode in tarin
mode_home_region = df_test['Home City'].mode()[0]
df_test['Home City'].fillna(mode_home_region, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2525383762.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Home City'].fillna(mode_home_region, inplace=True)

# %%
# Fill missing values in the 'Home Region' column with the mode in test
mode_home_region_test = df_test['Home Region'].mode()[0]
df_test['Home Region'].fillna(mode_home_region, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\126238829.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Home Region'].fillna(mode_home_region, inplace=True)

# %%
df_train['Program Main Category Code'].isnull().sum()
# Out:
# 0

# %%
df_train['Program Sub Category Code'].isnull().sum()
# Out:
# 935

# %%
df_train['Technology Type'].fillna('غير محدد', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\1856911654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Technology Type'].fillna('غير محدد', inplace=True)

# %%
df_test['Technology Type'].fillna('غير محدد', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2866996825.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Technology Type'].fillna('غير محدد', inplace=True)

# %%
mode_skill = df_train['Program Skill Level'].mode()[0]
df_train['Program Skill Level'].fillna(mode_skill, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\994432286.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Program Skill Level'].fillna(mode_skill, inplace=True)

# %%
mode_skill = df_train['Program Skill Level'].mode()[0]
df_test['Program Skill Level'].fillna(mode_skill, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\3378534780.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Program Skill Level'].fillna(mode_skill, inplace=True)

# %%
df_train['Education Speaciality'].fillna('غير محدد', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2455843452.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Education Speaciality'].fillna('غير محدد', inplace=True)

# %%
df_test['Education Speaciality'].fillna('غير محدد', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2919358606.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Education Speaciality'].fillna('غير محدد', inplace=True)

# %%
df_train.drop('College', axis=1, inplace=True)

# %%
df_test.drop('College', axis=1, inplace=True)

# %%
#Level of Education                  3
#Education Speaciality              37
df_train[['Level of Education', 'Education Speaciality' , 'Y']].sample(10)
# Out:
#      Level of Education                      Education Speaciality         Y
# 1043        البكالوريوس                         شبكات الحاسب الآلي      pass
# 888           الماجستير            Long Island University-New York      pass
# 3768        البكالوريوس                    نظم المعلومات الحاسوبية      pass
# 311         البكالوريوس                                  علوم حاسب      pass
# 4670        البكالوريوس                           Computer Science      pass
# 5523        البكالوريوس  هندسة الاتصالات والشبكات وتقنية المعلومات      pass
# 5424        البكالوريوس                              علوم الحاسبات      pass
# 3321        البكالوريوس                           Computer Science      pass
# 4654        البكالوريوس                                 امن سبراني  not pass
# 4511        البكالوريوس                              علوم الحاسبات      pass

# %%
#University Degree Score            11
#University Degree Score System     11
df_train[['University Degree Score', 'University Degree Score System' , 'Y']].sample(10)
# Out:
#       University Degree Score  University Degree Score System         Y
# 6039                     3.00                             5.0      pass
# 4247                     4.56                             5.0      pass
# 2861                     3.85                             5.0  not pass
# 925                      3.00                             5.0      pass
# 3372                     3.54                             4.0      pass
# 2119                     4.89                             5.0      pass
# 5811                     4.00                             5.0      pass
# 946                      3.23                             5.0      pass
# 1894                     4.00                             4.0  not pass
# 4288                     4.44                             5.0      pass

# %%
df_train[['University Degree Score', 'University Degree Score System']].isnull().sum()
# Out:
# University Degree Score           81
# University Degree Score System    81
# dtype: int64

# %%
df_train['University Degree Score'].notna().sum() == df_train['University Degree Score System'].notna().sum()
# Out:
# True

# %%
df_train['University Degree Score'].fillna(0, inplace=True)
df_train['University Degree Score System'].fillna(0, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\21318648.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['University Degree Score'].fillna(0, inplace=True)
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\21318648.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['University Degree Score System'].fillna(0, inplace=True)

# %%
df_test['University Degree Score'].fillna(0, inplace=True)
df_test['University Degree Score System'].fillna(0, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2794782551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['University Degree Score'].fillna(0, inplace=True)
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2794782551.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['University Degree Score System'].fillna(0, inplace=True)

# %%
# Calculate the mode of the 'Employment Status' column
mode_employment_status = df_train['Employment Status'].mode()[0]
# Fill missing values in the 'Employment Status' column with the mode
df_train['Employment Status'].fillna(mode_employment_status, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\900800843.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Employment Status'].fillna(mode_employment_status, inplace=True)

# %%
# Calculate the mode of the 'Employment Status' column
mode_employment_status = df_test['Employment Status'].mode()[0]
# Fill missing values in the 'Employment Status' column with the mode
df_test['Employment Status'].fillna(mode_employment_status, inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2723901641.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Employment Status'].fillna(mode_employment_status, inplace=True)

# %%
self_employed_rows = df_train[df_train['Employment Status'] == 'عمل حر']
print("Job Type and Still Working for rows where Employment Status is 'عمل حر':")
self_employed_rows[['Job Type', 'Still Working']].isnull().sum()
# Out:
# Job Type and Still Working for rows where Employment Status is 'عمل حر':
# Job Type         68
# Still Working    68
# dtype: int64

# %%
self_employed_rows = df_train[df_train['Employment Status'] == 'خريج']
print("Job Type and Still Working for rows where Employment Status is 'خريج':")
self_employed_rows[['Job Type', 'Still Working']].isnull().sum()
# Out:
# Job Type and Still Working for rows where Employment Status is 'خريج':
# Job Type         952
# Still Working    952
# dtype: int64

# %%
df_train['Job Type'].fillna('Undefined', inplace=True)
df_train['Still Working'].fillna('Undefined', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\3318682905.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Job Type'].fillna('Undefined', inplace=True)
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\3318682905.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Still Working'].fillna('Undefined', inplace=True)

# %%
df_test['Job Type'].fillna('Undefined', inplace=True)
df_test['Still Working'].fillna('Undefined', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\1910645674.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Job Type'].fillna('Undefined', inplace=True)
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\1910645674.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Still Working'].fillna('Undefined', inplace=True)

# %%
df_train['Level of Education'].fillna('غير محدد', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\3685162620.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Level of Education'].fillna('غير محدد', inplace=True)

# %%
df_test['Level of Education'].fillna('غير محدد', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\1954235943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Level of Education'].fillna('غير محدد', inplace=True)

# %%
df_train['Program Sub Category Code'].fillna('Undefined', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\2237639700.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Program Sub Category Code'].fillna('Undefined', inplace=True)

# %%
df_test['Program Sub Category Code'].fillna('Undefined', inplace=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17836\1651100335.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Program Sub Category Code'].fillna('Undefined', inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Student ID                        0
# Age                               0
# Gender                            0
# Home Region                       0
# Home City                         0
# Program ID                        0
# Program Main Category Code        0
# Program Sub Category Code         0
# Technology Type                   0
# Program Skill Level               0
# Program Presentation Method       0
# Program Start Date                0
# Program End Date                  0
# Program Days                      0
# Completed Degree                  0
# Level of Education                0
# Education Speaciality             0
# University Degree Score           0
# University Degree Score System    0
# Employment Status                 0
# Job Type                          0
# Still Working                     0
# Y                                 0
# dtype: int64

# %% [markdown]
# **Data Standardization**

# %%
def convert_score(score, score_system):
    if score_system == 4:
        return score * (5 / 4)
    elif score_system == 100:
        return score / 20
    else:
        return score
df_train['GPA'] = df_train.apply(lambda row: convert_score(row['University Degree Score'], row['University Degree Score System']), axis=1)
df_train.sample(20)
# Out:
#                                 Student ID   Age Gender  \
# 5958  99ab0e73-90d7-439e-9aa0-985e05c8ca63  25.0   أنثى
# 3566  69f7e4d1-62c4-4c64-92fe-c08ca482e495  27.0   أنثى
# 2549  b25bda02-808e-4bb4-81ff-e727c35361a4  22.0   أنثى
# 2140  7268c12b-eb54-4305-9f00-ca57cfad1519  31.0   أنثى
# 3589  15a79760-ec04-4a21-bec0-3d4ea8eb90e3  34.0   أنثى
# 6396  9aac9dc2-39c3-4ebd-ab1f-fc8705a4099d  24.0   أنثى
# 3320  2407997f-19ed-49b7-b9fa-b61924b3cea9  27.0   أنثى
# 439   ae20292b-2b0f-4ab9-bc28-43c140e28382  26.0   أنثى
# 6504  829964de-b692-4e74-9aac-29b6f62c32eb  22.0   أنثى
# 1511  b86e6d96-bcfe-4892-b901-e9deb2f26fff  25.0   أنثى
# 4831  4c76f658-8543-4a2f-bd72-60908c514246  31.0    ذكر
# 4101  06b9b3a9-3693-4f70-bee2-20165fb5f0b2  38.0   أنثى
# 461   5771cc15-41e6-419c-8320-661dcb1bc3f9  49.0    ذكر
# 4397  c57dda29-deaa-4666-92df-f732f9cf88e8  36.0    ذكر
# 2088  a86f1903-5672-4eb8-a150-d04a714d1fbe  24.0   أنثى
# 2752  292106c8-6db3-496e-ad1d-90bef58c2581  29.0   أنثى
# 2251  07efc555-2b92-4a62-a56c-f80507aab949  24.0    ذكر
# 1727  8376aec0-0e6c-47fc-9f0b-b055fcefc043  34.0    ذكر
# 30    215fabd5-3353-4bf8-9ed9-7dc35a57766f  24.0   أنثى
# 4926  dd20a5b4-4086-4f3e-8626-d64b5d829890  26.0    ذكر
#
#                 Home Region        Home City  \
# 5958           منطقة الرياض           الرياض
# 3566             منطقة حائل             حائل
# 2549        المنطقة الشرقية           الدمام
# 2140  منطقة المدينة المنورة  المدينة المنورة
# 3589           منطقة الرياض           الرياض
# 6396           منطقة الرياض           الرياض
# 3320           منطقة الرياض           الرياض
# 439            منطقة الرياض           الرياض
# 6504           منطقة الرياض           الرياض
# 1511           منطقة الرياض           الرياض
# 4831           منطقة الرياض           الرياض
# 4101           منطقة الرياض           الرياض
# 461            منطقة الرياض           الرياض
# 4397           منطقة الرياض           الرياض
# 2088           منطقة الرياض           الرياض
# 2752           منطقة الرياض           الرياض
# 2251           منطقة الرياض           الرياض
# 1727           منطقة الرياض           الرياض
# 30             منطقة الرياض           الرياض
# 4926      منطقة مكة المكرمة           الطائف
#
#                                 Program ID Program Main Category Code  \
# 5958  e006900d-05a9-4c2b-a36f-0ffb9fce44cd                       APMR
# 3566  f6feebca-cf2e-49f8-b3df-f3bb115cd241                       APMR
# 2549  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60                       APMR
# 2140  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60                       APMR
# 3589  6f905d3e-9eb9-4c40-ba6e-758c9a66fa72                       PCRF
# 6396  aee3a7b8-28ea-4b9d-963f-2f1413b81c04                       PCRF
# 3320  3d1b8482-4601-42fe-9ce2-1eed6c9a5ebe                       CAUF
# 439   67bbe41c-20c2-4799-9e15-eaae2e94f157                       APMR
# 6504  9b4cedaa-fac0-4eac-aa4b-b05b6a0c97ff                       PCRF
# 1511  33bc9c70-789e-46cd-a207-f1ee3a738f43                       APMR
# 4831  0fd432b1-7779-49cb-b203-000b90c9a6dd                       ABIR
# 4101  8605fbf3-9000-4492-b066-e2f1523abc79                       CAUF
# 461   e6be9f1a-dffa-4662-a7d2-74a6e12ad4b2                       CAUF
# 4397  60494e5b-b20a-4440-ab75-0fd257748dcc                       TOSL
# 2088  e006900d-05a9-4c2b-a36f-0ffb9fce44cd                       APMR
# 2752  1fb68d0e-0fc7-4178-9911-2ee82feed9c7                       PCRF
# 2251  ee8edc03-54db-45ad-9417-9e7df440c8d6                       CAUF
# 1727  d0f06377-196d-486c-bad8-15c04f8cdad3                       PCRF
# 30    786daedd-7fb3-4c4f-9c24-e19768b39ece                       APMR
# 4926  e0189c33-e562-4d49-8b09-c1cc3f9781c9                       INFA
#
#      Program Sub Category Code Technology Type Program Skill Level  ...  \
# 5958                 Undefined        غير محدد               متوسط  ...
# 3566                      SRTA        غير محدد               متوسط  ...
# 2549                      SWPS        غير محدد               متوسط  ...
# 2140                      SWPS        غير محدد               متوسط  ...
# 3589                      PCRF           داعمة               مبتدئ  ...
# 6396                      PCRF        غير محدد               متوسط  ...
# 3320                      ERST         تقليدية               متوسط  ...
# 439                  Undefined        غير محدد               متوسط  ...
# 6504                      PCRF        غير محدد               متوسط  ...
# 1511                      KLTM           ناشئة               متوسط  ...
# 4831                      INFA        غير محدد               متوسط  ...
# 4101                      SWPS         تقليدية               مبتدئ  ...
# 461                       SWPS           داعمة               مبتدئ  ...
# 4397                 Undefined           داعمة               متقدم  ...
# 2088                 Undefined        غير محدد               متوسط  ...
# 2752                      PCRF         تقليدية               متقدم  ...
# 2251                      SWPS        غير محدد               متوسط  ...
# 1727                      PCRF           ناشئة               مبتدئ  ...
# 30                   Undefined        غير محدد               متوسط  ...
# 4926                      INFA         تقليدية               متوسط  ...
#
#      Completed Degree Level of Education  \
# 5958              نعم        البكالوريوس
# 3566               لا        البكالوريوس
# 2549              نعم        البكالوريوس
# 2140              نعم        البكالوريوس
# 3589              نعم        البكالوريوس
# 6396              نعم        البكالوريوس
# 3320              نعم        البكالوريوس
# 439               نعم        البكالوريوس
# 6504              نعم        البكالوريوس
# 1511              نعم        البكالوريوس
# 4831              نعم        البكالوريوس
# 4101              نعم        البكالوريوس
# 461                لا          الماجستير
# 4397              نعم          الماجستير
# 2088              نعم        البكالوريوس
# 2752              نعم        البكالوريوس
# 2251              نعم        البكالوريوس
# 1727               لا        البكالوريوس
# 30                 لا        البكالوريوس
# 4926              نعم        البكالوريوس
#
#                        Education Speaciality  University Degree Score  \
# 5958                                غير محدد                     0.00
# 3566                         إدارة المعلومات                     4.74
# 2549                      نظم معلومات اداريه                     3.63
# 2140                             نظم معلومات                     4.48
# 3589                         الأمن السيبراني                     4.99
# 6396                           تقنيه معلومات                     4.41
# 3320                         تقنية المعلومات                     3.74
# 439                                علوم حاسب                     4.91
# 6504                           علوم الحاسبات                     4.00
# 1511                             نظم نعلومات                     3.53
# 4831                           علوم الحاسبات                     4.35
# 4101                                 انجليزي                    80.00
# 461                  هندسة الكترونيات مركبات                     4.50
# 4397  telecommunication and network engineer                     3.53
# 2088                               علوم حاسب                     4.77
# 2752                           تقنية معلومات                     4.39
# 2251                         الموارد البشرية                     3.78
# 1727                 علوم الحاسب و المعلومات                     3.00
# 30                           تقنية المعلومات                     4.00
# 4926                           نظم المعلومات                     3.62
#
#      University Degree Score System Employment Status   Job Type  \
# 5958                            0.0              موظف  Undefined
# 3566                            5.0              موظف  Undefined
# 2549                            4.0              طالب  Undefined
# 2140                            5.0          غير موظف  Undefined
# 3589                            5.0              موظف  Undefined
# 6396                            5.0              موظف  Undefined
# 3320                            5.0          غير موظف  Undefined
# 439                             5.0              موظف  Undefined
# 6504                            5.0       موظف - طالب  دوام جزئي
# 1511                            5.0              خريج  Undefined
# 4831                            5.0              موظف  دوام كامل
# 4101                          100.0              خريج  Undefined
# 461                             5.0              موظف  Undefined
# 4397                            4.0              موظف  Undefined
# 2088                            5.0              خريج  Undefined
# 2752                            5.0              موظف  Undefined
# 2251                            5.0          غير موظف  Undefined
# 1727                            5.0              موظف  Undefined
# 30                              5.0          غير موظف      تدريب
# 4926                            5.0              موظف  Undefined
#
#       Still Working         Y     GPA
# 5958      Undefined      pass  0.0000
# 3566      Undefined      pass  4.7400
# 2549      Undefined      pass  4.5375
# 2140      Undefined      pass  4.4800
# 3589      Undefined      pass  4.9900
# 6396      Undefined      pass  4.4100
# 3320      Undefined      pass  3.7400
# 439       Undefined      pass  4.9100
# 6504            Yes      pass  4.0000
# 1511      Undefined      pass  3.5300
# 4831            Yes      pass  4.3500
# 4101      Undefined      pass  4.0000
# 461       Undefined  not pass  4.5000
# 4397      Undefined      pass  4.4125
# 2088      Undefined      pass  4.7700
# 2752      Undefined      pass  4.3900
# 2251      Undefined      pass  3.7800
# 1727      Undefined  not pass  3.0000
# 30               No      pass  4.0000
# 4926      Undefined      pass  3.6200
#
# [20 rows x 24 columns]

# %%
def convert_score(score, score_system):
    if score_system == 4:
        return score * (5 / 4)
    elif score_system == 100:
        return score / 20
    else:
        return score
df_test['GPA'] = df_test.apply(lambda row: convert_score(row['University Degree Score'], row['University Degree Score System']), axis=1)
df_test.sample(20)
# Out:
#                                Student ID   Age Gender        Home Region  \
# 689  b07812ae-53f6-46ca-8d42-5ae649bd5e81  32.0   أنثى       منطقة الرياض
# 324  a09b88fa-1f10-4726-af8d-c3fecd3c64a7  28.0   أنثى       منطقة الرياض
# 150  8ec37c5e-bd3d-47a9-92c8-b9286a6aaa3a  21.0    ذكر       منطقة الرياض
# 145  c0807aea-63c6-4a71-9422-b15ab7eef8b4  19.0   أنثى       منطقة الرياض
# 120  51597523-0a11-40eb-b937-0c783d1db0ff  29.0   أنثى  منطقة مكة المكرمة
# 439  1204478e-09eb-43ed-99f4-19b0d66592a9  23.0   أنثى       منطقة الرياض
# 195  ebb55a52-36fa-4bcb-b89c-b8eaad6d612a  19.0   أنثى       منطقة الرياض
# 250  b5dda63b-428d-49bc-bd25-f57234a6cce9  26.0    ذكر       منطقة الرياض
# 499  7b3a0414-8254-430c-ab27-ea908b0c7a2d  24.0    ذكر       منطقة الرياض
# 182  6c272a94-112f-4105-9cef-4ff5da0ff3cb  25.0   أنثى  منطقة مكة المكرمة
# 206  80397860-ade2-4304-a2bf-a0cdb896569b  27.0    ذكر       منطقة الرياض
# 117  67454a0e-ea7d-4433-903e-edd2bd94cd1d  28.0   أنثى       منطقة القصيم
# 772  0c408c5b-4401-44a4-bdf6-16dd9081433c  25.0   أنثى       منطقة الرياض
# 566  6062c470-594e-43c9-855a-428a6b4c54e0  25.0    ذكر       منطقة الرياض
# 200  2e476b9f-b136-4da3-8e75-22e0dc6de762  28.0   أنثى       منطقة الرياض
# 790  4369cfc1-c93f-449b-9b26-5b4b1cac5b96  25.0   أنثى       منطقة الرياض
# 254  eb9071ac-5d4e-4500-adda-5e7b028cf59c  22.0   أنثى  منطقة مكة المكرمة
# 226  57047ca5-2bf5-4870-933b-675d3276071c  24.0   أنثى       منطقة الرياض
# 334  52e74fbd-5eaf-448a-8bea-6ff7d890bc97  31.0    ذكر       منطقة الرياض
# 704  fbc2bb99-4807-4947-acde-109bd97ee955  26.0   أنثى  منطقة مكة المكرمة
#
#     Home City                            Program ID  \
# 689    الرياض  75615c77-f45c-4ccb-a747-bb4bbcb311b2
# 324    الرياض  240d70d5-7735-4c39-92c0-bd2f4f99facd
# 150    الرياض  02d387ca-5045-47ea-bcaa-8c94e747cc1a
# 145    الرياض  1d84b96c-af85-4ced-babc-31c369ee9ab0
# 120       جدة  daf89fda-a75f-487c-a30c-0b65de513e32
# 439    الرياض  b3c56c6d-dd46-4f26-93ee-c16e211aa3b9
# 195    الرياض  aee3a7b8-28ea-4b9d-963f-2f1413b81c04
# 250    الرياض  53efebf0-6779-48c2-9c72-2e0e7c2bf175
# 499    الرياض  a5a9e969-2d2d-4a17-a8e9-b1589d970847
# 182       جدة  e58677d9-20ef-43a4-955e-e78e2989cc91
# 206    الرياض  ab263106-20a8-42aa-9626-278e62ae3a49
# 117      الرس  46e7d55e-f11d-47c3-8310-a907c1584671
# 772    الرياض  ee2e00ae-4645-4821-bf20-eea765a5c51d
# 566    الرياض  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 200    الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 790    الرياض  a0282350-7236-47f4-acd0-88cfb67ade07
# 254       جدة  c72206c7-3127-4d96-a458-fc9ccd90b4a8
# 226    الرياض  aee3a7b8-28ea-4b9d-963f-2f1413b81c04
# 334    الرياض  46e7d55e-f11d-47c3-8310-a907c1584671
# 704       جدة  f525fd4a-d0bd-4278-b69b-1824604d6092
#
#     Program Main Category Code Program Sub Category Code Technology Type  \
# 689                       TOSL                      TOSL         تقليدية
# 324                       PCRF                      PCRF         تقليدية
# 150                       CAUF                      SWPS         تقليدية
# 145                       CAUF                 Undefined        غير محدد
# 120                       CAUF                 Undefined        غير محدد
# 439                       PCRF                      PCRF           داعمة
# 195                       PCRF                      PCRF        غير محدد
# 250                       PCRF                      PCRF        غير محدد
# 499                       CAUF                      SWPS        غير محدد
# 182                       INFA                      INFA        غير محدد
# 206                       CAUF                      SWPS         تقليدية
# 117                       ABIR                 Undefined         تقليدية
# 772                       APMR                      SRTA         تقليدية
# 566                       TOSL                      TOSL        غير محدد
# 200                       PCRF                      PCRF         تقليدية
# 790                       CAUF                      CRDP           داعمة
# 254                       APMR                      ASCW         تقليدية
# 226                       PCRF                      PCRF        غير محدد
# 334                       ABIR                 Undefined         تقليدية
# 704                       SERU                      ERST         تقليدية
#
#     Program Skill Level  ... Program Days Completed Degree Level of Education  \
# 689               متوسط  ...            5              نعم        البكالوريوس
# 324               متقدم  ...            4              نعم        البكالوريوس
# 150               مبتدئ  ...            5              نعم        البكالوريوس
# 145               مبتدئ  ...            5               لا        البكالوريوس
# 120               مبتدئ  ...            5              نعم        البكالوريوس
# 439               مبتدئ  ...           12              نعم        البكالوريوس
# 195               متوسط  ...           12               لا            الدبلوم
# 250               متوسط  ...            5              نعم        البكالوريوس
# 499               متوسط  ...           12              نعم        البكالوريوس
# 182               متوسط  ...           12              نعم        البكالوريوس
# 206               متقدم  ...            5              نعم        البكالوريوس
# 117               مبتدئ  ...            5              نعم        البكالوريوس
# 772               متوسط  ...            5               لا            الدبلوم
# 566               متوسط  ...           33              نعم        البكالوريوس
# 200               متوسط  ...           12              نعم              ثانوي
# 790               مبتدئ  ...            5               لا        البكالوريوس
# 254               متقدم  ...           12              نعم        البكالوريوس
# 226               متوسط  ...           12              نعم        البكالوريوس
# 334               مبتدئ  ...            5              نعم        البكالوريوس
# 704               متوسط  ...            5              نعم            الدبلوم
#
#              Education Speaciality University Degree Score  \
# 689                تقنية المعلومات                   3.540
# 324             شبكات الحاسب الآلي                   2.730
# 150                تقنية المعلومات                   4.500
# 145                  علوم الحاسبات                   5.000
# 120                  علوم الحاسبات                   3.830
# 439  الامن السيراني والتحري الرقمي                   4.684
# 195                        البرمجه                   3.990
# 250                          هندسة                   4.280
# 499                      علوم حاسب                   4.000
# 182                      علوم حاسب                   4.820
# 206                  علوم الحاسبات                   3.320
# 117                    نظم معلومات                   3.110
# 772                    تصميم مواقع                   3.860
# 566                   هندسة الحاسب                   3.360
# 200                       غير محدد                  82.000
# 790                         محاسبة                   3.240
# 254                  علوم الحاسبات                   4.970
# 226                تقنية المعلومات                   3.900
# 334               هندسة إلكترونيات                   2.830
# 704    الجرافيكس والوسائط المتعددة                   4.000
#
#     University Degree Score System Employment Status   Job Type  \
# 689                            5.0              موظف  دوام كامل
# 324                            5.0              موظف  دوام كامل
# 150                            5.0              طالب  Undefined
# 145                            5.0              طالب  Undefined
# 120                            5.0          غير موظف  دوام كامل
# 439                            5.0              خريج  Undefined
# 195                            5.0              خريج  Undefined
# 250                            5.0              موظف  Undefined
# 499                            5.0              طالب  Undefined
# 182                            5.0          غير موظف  Undefined
# 206                            5.0              موظف  دوام كامل
# 117                            4.0          غير موظف  Undefined
# 772                            5.0              خريج  Undefined
# 566                            5.0              خريج  Undefined
# 200                          100.0              موظف  Undefined
# 790                            4.0              موظف  Undefined
# 254                            5.0              موظف      تدريب
# 226                            5.0              موظف  دوام كامل
# 334                            4.0              موظف  Undefined
# 704                            5.0              موظف  دوام كامل
#
#      Still Working     GPA
# 689            Yes  3.5400
# 324            Yes  2.7300
# 150      Undefined  4.5000
# 145      Undefined  5.0000
# 120             No  3.8300
# 439      Undefined  4.6840
# 195      Undefined  3.9900
# 250      Undefined  4.2800
# 499      Undefined  4.0000
# 182      Undefined  4.8200
# 206            Yes  3.3200
# 117      Undefined  3.8875
# 772      Undefined  3.8600
# 566      Undefined  3.3600
# 200      Undefined  4.1000
# 790      Undefined  4.0500
# 254            Yes  4.9700
# 226            Yes  3.9000
# 334      Undefined  3.5375
# 704            Yes  4.0000
#
# [20 rows x 23 columns]

# %%
df_test.to_csv('Data/cleaned_test_data.csv')

# %%
df_train.to_csv('Data/cleaned_train_data.csv')
